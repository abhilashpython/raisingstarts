# %%
import pandas as pd

# %%
df = pd.read_csv('data1.csv')

# %%
print type(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(10)
# Out:
#    id   name6    sal  age
# 0   6   name6  45689   24
# 1   7   name7  45690   24
# 2   8   name8  45691   25
# 3   9   name9  45692   25
# 4  10  name10  45693   26
# 5  11  name11  45694   26
# 6  12  name12  45695   25
# 7  13  name13  45696   25
# 8  14  name14  45697   26
# 9  15  name15  45698   26

# %%
df.tail(10)
# Out:
#     id   name6    sal  age
# 16  22  name22  45705   28
# 17  23  name23  45706   28
# 18  24  name24  45707   27
# 19  25  name25  45708   27
# 20  26  name26  45709   28
# 21  27  name27  45710   28
# 22  28  name28  45711   29
# 23  29  name29  45712   29
# 24  30  name30  45713   28
# 25  31  name31  45714   28

# %%
df.ix[0]
# Out:
# id           6
# name6    name6
# sal      45689
# age         24
# Name: 0, dtype: object

# %%
df
# Out:
#     id   name6    sal  age
# 0    6   name6  45689   24
# 1    7   name7  45690   24
# 2    8   name8  45691   25
# 3    9   name9  45692   25
# 4   10  name10  45693   26
# 5   11  name11  45694   26
# 6   12  name12  45695   25
# 7   13  name13  45696   25
# 8   14  name14  45697   26
# 9   15  name15  45698   26
# 10  16  name16  45699   27
# 11  17  name17  45700   27
# 12  18  name18  45701   26
# 13  19  name19  45702   26
# 14  20  name20  45703   27
# 15  21  name21  45704   27
# 16  22  name22  45705   28
# 17  23  name23  45706   28
# 18  24  name24  45707   27
# 19  25  name25  45708   27
# 20  26  name26  45709   28
# 21  27  name27  45710   28
# 22  28  name28  45711   29
# 23  29  name29  45712   29
# 24  30  name30  45713   28
# 25  31  name31  45714   28

# %%
df['id']
# Out:
# 0      6
# 1      7
# 2      8
# 3      9
# 4     10
# 5     11
# 6     12
# 7     13
# 8     14
# 9     15
# 10    16
# 11    17
# 12    18
# 13    19
# 14    20
# 15    21
# 16    22
# 17    23
# 18    24
# 19    25
# 20    26
# 21    27
# 22    28
# 23    29
# 24    30
# 25    31
# Name: id, dtype: int64

# %%
df['sal'].mean()
# Out:
# 45701.5

# %%
df['sal'].sum()
# Out:
# 1188239

# %%
sal=df['sal']

# %%
print type(sal)
# Out:
# <class 'pandas.core.series.Series'>

# %%
df = pd.read_csv('data1.csv')

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN         NaN         NaN
# 1          id      name6        sal        age         doj         NaN
# 2           6      name6      45689         24  1990-01-01         NaN
# 3           7      name7      45690         24  1990-02-02         NaN
# 4           8      name8      45691         25  1990-03-06         NaN
# 5           9      name9      45692         25  1990-04-07         NaN
# 6          10     name10      45693         26  1990-05-09         NaN
# 7          11     name11      45694         26  1990-06-10         NaN
# 8          12     name12      45695         25  1990-07-12         NaN
# 9          13     name13      45696         25  1990-08-13         NaN
# 10         14     name14      45697         26  1990-09-14         NaN
# 11         15     name15      45698         26  1990-10-16         NaN
# ...

# %%
df = pd.read_csv('data1.csv',skiprows=2,skipfooter=2)
# Out:
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df
# Out:
#     id   name6    sal  age         doj  Unnamed: 5  Unnamed: 6
# 0    6   name6  45689   24  1990-01-01         NaN         NaN
# 1    7   name7  45690   24  1990-02-02         NaN         NaN
# 2    8   name8  45691   25  1990-03-06         NaN         NaN
# 3    9   name9  45692   25  1990-04-07         NaN         NaN
# 4   10  name10  45693   26  1990-05-09         NaN         NaN
# 5   11  name11  45694   26  1990-06-10         NaN         NaN
# 6   12  name12  45695   25  1990-07-12         NaN         NaN
# 7   13  name13  45696   25  1990-08-13         NaN         NaN
# 8   14  name14  45697   26  1990-09-14         NaN         NaN
# 9   15  name15  45698   26  1990-10-16         NaN         NaN
# 10  16  name16  45699   27  1990-11-17         NaN         NaN
# 11  17  name17  45700   27  1990-12-19         NaN         NaN
# 12  18  name18  45701   26  1991-01-20         NaN         NaN
# 13  19  name19  45702   26  1991-02-21         NaN         NaN
# ...

# %%
for i in df['doj'][:10]:
    print i,type(i)
# Out:
# 1990-01-01 <type 'str'>
# 1990-02-02 <type 'str'>
# 1990-03-06 <type 'str'>
# 1990-04-07 <type 'str'>
# 1990-05-09 <type 'str'>
# 1990-06-10 <type 'str'>
# 1990-07-12 <type 'str'>
# 1990-08-13 <type 'str'>
# 1990-09-14 <type 'str'>
# 1990-10-16 <type 'str'>

# %%
df = pd.read_csv('data1.csv',skiprows=2,skipfooter=2,parse_dates=[4])
df = df.head(5)
# Out:
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df
# Out:
#    id   name6    sal  age        doj  Unnamed: 5  Unnamed: 6
# 0   6   name6  45689   24 1990-01-01         NaN         NaN
# 1   7   name7  45690   24 1990-02-02         NaN         NaN
# 2   8   name8  45691   25 1990-03-06         NaN         NaN
# 3   9   name9  45692   25 1990-04-07         NaN         NaN
# 4  10  name10  45693   26 1990-05-09         NaN         NaN

# %%
for i in df['doj']:
    print type(i)
# Out:
# <class 'pandas.tslib.Timestamp'>
# <class 'pandas.tslib.Timestamp'>
# <class 'pandas.tslib.Timestamp'>
# <class 'pandas.tslib.Timestamp'>
# <class 'pandas.tslib.Timestamp'>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
for i in df.index:
    print i
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
df = pd.read_csv('data1.csv',skiprows=2,skipfooter=2,parse_dates=[4])
# Out:
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df[df['sal']>45697]
# Out:
#     2016-01-01  id   name6    sal  age         doj  Unnamed: 6  Unnamed: 7
# 9   2016-01-11  15  name15  45698   26  1990-10-16         NaN         NaN
# 10  2016-01-12  16  name16  45699   27  1990-11-17         NaN         NaN
# 11  2016-01-13  17  name17  45700   27  1990-12-19         NaN         NaN
# 12  2016-01-14  18  name18  45701   26  1991-01-20         NaN         NaN
# 13  2016-01-15  19  name19  45702   26  1991-02-21         NaN         NaN
# 14  2016-01-16  20  name20  45703   27  1991-03-25         NaN         NaN
# 15  2016-01-17  21  name21  45704   27  1991-04-26         NaN         NaN
# 16  2016-01-18  22  name22  45705   28  1991-05-28         NaN         NaN
# 17  2016-01-19  23  name23  45706   28  1991-06-29         NaN         NaN
# 18  2016-01-20  24  name24  45707   27  1991-07-31         NaN         NaN
# 19  2016-01-21  25  name25  45708   27  1991-09-01         NaN         NaN
# ...

# %%
df = pd.read_csv('data1.csv',skiprows=2,skipfooter=2,parse_dates=[4],index_col=0)
# Out:
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df.head()
# Out:
#             id   name6    sal  age         doj  Unnamed: 6  Unnamed: 7
# 2016-01-01
# 2016-01-02   6   name6  45689   24  1990-01-01         NaN         NaN
# 2016-01-03   7   name7  45690   24  1990-02-02         NaN         NaN
# 2016-01-04   8   name8  45691   25  1990-03-06         NaN         NaN
# 2016-01-05   9   name9  45692   25  1990-04-07         NaN         NaN
# 2016-01-06  10  name10  45693   26  1990-05-09         NaN         NaN

# %%
data_table = pd.read_html('www.w3schools.com/html/html_tables.asp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-0a4e51b08331> in <module>()
# ----> 1 data_table = pd.read_html('www.w3schools.com/html/html_tables.asp')
#
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     868     _validate_header_arg(header)
#     869     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 870                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     730             break
#     731     else:
# --> 732         raise_with_traceback(retained)
#     733
#     734     ret = []
# ...

# %%
df
# Out:
#             id   name6    sal  age         doj  Unnamed: 6  Unnamed: 7
# 2016-01-01
# 2016-01-02   6   name6  45689   24  1990-01-01         NaN         NaN
# 2016-01-03   7   name7  45690   24  1990-02-02         NaN         NaN
# 2016-01-04   8   name8  45691   25  1990-03-06         NaN         NaN
# 2016-01-05   9   name9  45692   25  1990-04-07         NaN         NaN
# 2016-01-06  10  name10  45693   26  1990-05-09         NaN         NaN
# 2016-01-07  11  name11  45694   26  1990-06-10         NaN         NaN
# 2016-01-08  12  name12  45695   25  1990-07-12         NaN         NaN
# 2016-01-09  13  name13  45696   25  1990-08-13         NaN         NaN
# 2016-01-10  14  name14  45697   26  1990-09-14         NaN         NaN
# 2016-01-11  15  name15  45698   26  1990-10-16         NaN         NaN
# 2016-01-12  16  name16  45699   27  1990-11-17         NaN         NaN
# 2016-01-13  17  name17  45700   27  1990-12-19         NaN         NaN
# ...

# %%
d=[{'id':1,'name':'name1','sal':12345},
    {'id':3,'name':'name3','sal':12347},
  {'id':2,'name':'name2','sal':12346},
  {'id':4,'name':'name4','sal':12349},
  {'id':5,'name':'name5','sal':12350},
  ]

# %%
data = pd.DataFrame(d)

# %%
data
# Out:
#    id   name    sal
# 0   1  name1  12345
# 1   3  name3  12347
# 2   2  name2  12346
# 3   4  name4  12349
# 4   5  name5  12350

# %%
data.sort_values(by='sal')
# Out:
#    id   name    sal
# 0   1  name1  12345
# 2   2  name2  12346
# 1   3  name3  12347
# 3   4  name4  12349
# 4   5  name5  12350

# %%
data
# Out:
#    id   name    sal
# 0   1  name1  12345
# 1   3  name3  12347
# 2   2  name2  12346
# 3   4  name4  12349
# 4   5  name5  12350

# %%
data.sort_values(by='sal',inplace=True)

# %%
data
# Out:
#    id   name    sal
# 0   1  name1  12345
# 2   2  name2  12346
# 1   3  name3  12347
# 3   4  name4  12349
# 4   5  name5  12350

# %%
#https://www.youtube.com/watch?v=0CFFTJUZ2dc
#http://pandas.pydata.org/pandas-docs/stable/10min.html

# %%
import pandas as pd

# %%
data = pd.read_csv('data1.csv')

# %%
data.head()
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0  createdateandtime        NaN        NaN        NaN        NaN         NaN
# 1         2016-01-01         id      name6        sal        age         doj
# 2         2016-01-02          6      name6      45689         24  1990-01-01
# 3         2016-01-03          7      name7      45690         24  1990-02-02
# 4         2016-01-04          8      name8      45691         25  1990-03-06
#
#    Unnamed: 6           data about a person
# 0         NaN  filter data as on 2013-08-09
# 1         NaN                           NaN
# 2         NaN                           NaN
# 3         NaN                           NaN
# 4         NaN                           NaN

# %%
df = pd.read_csv('data1.csv',skiprows=2,skipfooter=2)
# Out:
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df
# Out:
#    createdateandtime  id    name    sal  age         doj  Unnamed: 6  \
# 0         2016-01-02   6   name6  45689   24  1990-01-01         NaN
# 1         2016-01-03   7   name7  45690   24  1990-02-02         NaN
# 2         2016-01-04   8   name8  45691   25  1990-03-06         NaN
# 3         2016-01-05   9   name9  45692   25  1990-04-07         NaN
# 4         2016-01-06  10  name10  45693   26  1990-05-09         NaN
# 5         2016-01-07  11  name11  45694   26  1990-06-10         NaN
# 6         2016-01-08  12  name12  45695   25  1990-07-12         NaN
# 7         2016-01-09  13  name13  45696   25  1990-08-13         NaN
# 8         2016-01-10  14  name14  45697   26  1990-09-14         NaN
# 9         2016-01-11  15  name15  45698   26  1990-10-16         NaN
# 10        2016-01-12  16  name16  45699   27  1990-11-17         NaN
# 11        2016-01-13  17  name17  45700   27  1990-12-19         NaN
# 12        2016-01-14  18  name18  45701   26  1991-01-20         NaN
# ...

# %%
df_group = df.groupby('age')

# %%
df_group

# %%
df_group.sum()
# Out:
#       id     sal  Unnamed: 6  Unnamed: 7
# age
# 24    13   91379         NaN         NaN
# 25    42  182774         NaN         NaN
# 26    87  274185         NaN         NaN
# 27   123  274221         NaN         NaN
# 28   159  274257         NaN         NaN
# 29    57   91423         NaN         NaN

# %%
df_group.sum()['sal']
# Out:
# age
# 24     91379
# 25    182774
# 26    274185
# 27    274221
# 28    274257
# 29     91423
# Name: sal, dtype: int64

# %%
df_group = df.groupby('age')
df_group.count()
# Out:
#      createdateandtime  id  name  sal  doj  Unnamed: 6  Unnamed: 7
# age
# 24                   2   2     2    2    2           0           0
# 25                   4   4     4    4    4           0           0
# 26                   6   6     6    6    6           0           0
# 27                   6   6     6    6    6           0           0
# 28                   6   6     6    6    6           0           0
# 29                   2   2     2    2    2           0           0

# %%
df
# Out:
#    createdateandtime  id    name    sal  age         doj  Unnamed: 6  \
# 0         2016-01-02   6   name6  45689   24  1990-01-01         NaN
# 1         2016-01-03   7   name7  45690   24  1990-02-02         NaN
# 2         2016-01-04   8   name8  45691   25  1990-03-06         NaN
# 3         2016-01-05   9   name9  45692   25  1990-04-07         NaN
# 4         2016-01-06  10  name10  45693   26  1990-05-09         NaN
# 5         2016-01-07  11  name11  45694   26  1990-06-10         NaN
# 6         2016-01-08  12  name12  45695   25  1990-07-12         NaN
# 7         2016-01-09  13  name13  45696   25  1990-08-13         NaN
# 8         2016-01-10  14  name14  45697   26  1990-09-14         NaN
# 9         2016-01-11  15  name15  45698   26  1990-10-16         NaN
# 10        2016-01-12  16  name16  45699   27  1990-11-17         NaN
# 11        2016-01-13  17  name17  45700   27  1990-12-19         NaN
# 12        2016-01-14  18  name18  45701   26  1991-01-20         NaN
# ...

# %%
persons1=[{'id':1,'name':'name1'},
          {'id':2,'name':'name2'},
          {'id':3,'name':'name3'},
         ]

# %%
df1=pd.DataFrame(persons1)

# %%
persons2=[{'id':4,'name':'name4'},
          {'id':5,'name':'name5'},
          {'id':6,'name':'name6'},
         ]

# %%
df2=pd.DataFrame(persons2)

# %%
df1
# Out:
#    id   name
# 0   1  name1
# 1   2  name2
# 2   3  name3

# %%
df2
# Out:
#    id   name
# 0   4  name4
# 1   5  name5
# 2   6  name6

# %%
df3 = pd.merge(df1,df2,how="left")

# %%
df3
# Out:
#    id   name
# 0   1  name1
# 1   2  name2
# 2   3  name3

# %%
df3 = pd.merge(df1,df2,how="right")

# %%
df3
# Out:
#    id   name
# 0   4  name4
# 1   5  name5
# 2   6  name6

# %%
df1
# Out:
#    id   name
# 0   1  name1
# 1   2  name2
# 2   3  name3

# %%
df2
# Out:
#    id   name
# 0   4  name4
# 1   5  name5
# 2   6  name6

# %%
df2.index=range(3,6)

# %%
df2
# Out:
#    id   name
# 3   4  name4
# 4   5  name5
# 5   6  name6

# %%
df3 = pd.merge(df1,df2,how="left")

# %%
df3
# Out:
#    id   name
# 0   1  name1
# 1   2  name2
# 2   3  name3

# %%
df2.index
# Out:
# Int64Index([3, 4, 5], dtype='int64')

# %%
df2
# Out:
#    id   name
# 3   4  name4
# 4   5  name5
# 5   6  name6

# %%
df2['age']=[23,24,25]

# %%
df2
# Out:
#    id   name  age
# 3   4  name4   23
# 4   5  name5   24
# 5   6  name6   25

# %%
df2.index=[0,1,2]

# %%
df1
# Out:
#    id   name
# 0   1  name1
# 1   2  name2
# 2   3  name3

# %%
df2
# Out:
#    id   name  age
# 0   4  name4   23
# 1   5  name5   24
# 2   6  name6   25

# %%
df3=pd.merge(df1,df2,how="right")

# %%
df3
# Out:
#    id   name  age
# 0   4  name4   23
# 1   5  name5   24
# 2   6  name6   25

# %%
df3=pd.merge(df1,df2,how="left")

# %%
df3
# Out:
#    id   name  age
# 0   1  name1  NaN
# 1   2  name2  NaN
# 2   3  name3  NaN

# %%
data.head(5)
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0  createdateandtime        NaN        NaN        NaN        NaN         NaN
# 1         2016-01-01         id      name6        sal        age         doj
# 2         2016-01-02          6      name6      45689         24  1990-01-01
# 3         2016-01-03          7      name7      45690         24  1990-02-02
# 4         2016-01-04          8      name8      45691         25  1990-03-06
#
#    Unnamed: 6           data about a person
# 0         NaN  filter data as on 2013-08-09
# 1         NaN                           NaN
# 2         NaN                           NaN
# 3         NaN                           NaN
# 4         NaN                           NaN

# %%
data = pd.read_csv('data1.csv',skiprows=2,skipfooter=2)
# Out:
# /home/tcloudost/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
data
# Out:
#    createdateandtime  id    name    sal  age         doj  Unnamed: 6  \
# 0         2016-01-02   6   name6  45689   24  1990-01-01         NaN
# 1         2016-01-03   7   name7  45690   24  1990-02-02         NaN
# 2         2016-01-04   8   name8  45691   25  1990-03-06         NaN
# 3         2016-01-05   9   name9  45692   25  1990-04-07         NaN
# 4         2016-01-06  10  name10  45693   26  1990-05-09         NaN
# 5         2016-01-07  11  name11  45694   26  1990-06-10         NaN
# 6         2016-01-08  12  name12  45695   25  1990-07-12         NaN
# 7         2016-01-09  13  name13  45696   25  1990-08-13         NaN
# 8         2016-01-10  14  name14  45697   26  1990-09-14         NaN
# 9         2016-01-11  15  name15  45698   26  1990-10-16         NaN
# 10        2016-01-12  16  name16  45699   27  1990-11-17         NaN
# 11        2016-01-13  17  name17  45700   27  1990-12-19         NaN
# 12        2016-01-14  18  name18  45701   26  1991-01-20         NaN
# ...

# %%
data_json = data.to_json()

# %%
data.to_csv("data3.csv")
# Out:
# '{"createdateandtime":{"0":"2016-01-02","1":"2016-01-03","2":"2016-01-04","3":"2016-01-05","4":"2016-01-06","5":"2016-01-07","6":"2016-01-08","7":"2016-01-09","8":"2016-01-10","9":"2016-01-11","10":"2016-01-12","11":"2016-01-13","12":"2016-01-14","13":"2016-01-15","14":"2016-01-16","15":"2016-01-17","16":"2016-01-18","17":"2016-01-19","18":"2016-01-20","19":"2016-01-21","20":"2016-01-22","21":"2016-01-23","22":"2016-01-24","23":"2016-01-25","24":"2016-01-26","25":"2016-01-27"},"id":{"0":6,"1":7,"2":8,"3":9,"4":10,"5":11,"6":12,"7":13,"8":14,"9":15,"10":16,"11":17,"12":18,"13":19,"14":20,"15":21,"16":22,"17":23,"18":24,"19":25,"20":26,"21":27,"22":28,"23":29,"24":30,"25":31},"name":{"0":"name6","1":"name7","2":"name8","3":"name9","4":"name10","5":"name11","6":"name12","7":"name13","8":"name14","9":"name15","10":"name16","11":"name17","12":"name18","13":"name19","14":"name20","15":"name21","16":"name22","17":"name23","18":"name24","19":"name25","20":"name26","21":"name27","22":"name28"
# ...
